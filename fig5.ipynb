# %%
import sys; sys.path.append('..')
import numpy as np, elastic_rods
from bending_validation import suppress_stdout
from linkage_vis import LinkageViewer

l = elastic_rods.RodLinkage('/home/bruce/ElasticRods/examples/wenbo_model.obj')
driver=l.centralJoint()

mat = elastic_rods.RodMaterial('Rectangle', 7.2e10, 0.22, [0.8,0.1], stiffAxis=elastic_rods.StiffAxis.D2)
l.setMaterial(mat)

with suppress_stdout(): elastic_rods.restlen_solve(l)
jdo = l.dofOffsetForJoint(driver)
# fixedVars = list(range(jdo, jdo + 6)) # fix rigid motion for a single joint
# fixedVars.append(jdo + 6) # constrain angle at the driving joint
fixedVars=[]
point_ind=l.jointPositionDoFIndices()
point_pos=l.jointPositions()
for i in range(0,len(point_ind)): 
    if point_pos[i]==0:
        if point_ind[i]%3==2:
            fixedVars.append(point_ind[i-2])
            fixedVars.append(point_ind[i-1])
            fixedVars.append(point_ind[i])
with suppress_stdout(): elastic_rods.compute_equilibrium(l, fixedVars=fixedVars)

view = LinkageViewer(l, width=1024)
view.show()
# print(fixedVars)
# Out:
# Renderer(camera=PerspectiveCamera(aspect=2.0, children=(PointLight(color='white', intensity=0.6, position=(0.0…

# %%
l.saveVisualizationGeometry('5_deployed_meshID_1693d9a2-45c1-416b-8c7a-96ab881d1320.obj')
#l.writeLinkageDebugData('')

# %%
#the stuff below will write a line model of the deployed stated
l.writeLinkageDebugData('5_deployed_1693d9a2-45c1-416b-8c7a-96ab881d1320.msh')
from linkage_utils import writeRodSegments
#the stuff below will write the polyline matching
writeRodSegments(l,'5_olyline_segments_pi3plus2pi12_1693d9a2-45c1-416b-8c7a-96ab881d1320.txt', zeroBasedIndexing=True)
#l.writeLinkageDebugData('')

# %%
np.savetxt('5_restlen_meshID_1a219f3e-c853-4985-ad5f-f13b369c0e63.txt',l.getPerSegmentRestLength())

# %%
from open_linkage import open_linkage
def equilibriumSolver(tgtAngle, l, opts, fv):
    opts.beta = 1e-8
    opts.gradTol = 1e-4
    opts.useIdentityMetric = False
    return elastic_rods.compute_equilibrium(l, tgtAngle, options=opts, fixedVars=[3489, 3490, 3491, 3543, 3544, 3545, 3705, 3706, 3707, 3750, 3751, 3752, 3903, 3904, 3905, 3930, 3931, 3932, 3993, 3994, 3995, 4020, 4021, 4022, 4074, 4075, 4076, 4101, 4102, 4103])
# open_linkage(l, driver, 2 * np.pi/3, 25, view, zPerturbationEpsilon=0, equilibriumSolver=equilibriumSolver, maxNewtonIterationsIntermediate=20, verbose=10, useTargetAngleConstraint=False);
open_linkage(l, driver, np.deg2rad(115) - l.averageJointAngle, 50, view, zPerturbationEpsilon=0, equilibriumSolver=equilibriumSolver, maxNewtonIterationsIntermediate=20, verbose=10, useTargetAngleConstraint=True);
# Out:
# target angle:  0.24860646971382477
# 0	8.44377e+06	1.01721e+08	1.01721e+08	1	0
# Backtracking failed.
# 0.3052153726992525	6807161.3133200705	6807161.3133200705	32582.26384658883	6774579.0427848445	0.00668864049928229
# target angle:  0.28449467726647076
# 0	8.45469e+06	1.01415e+08	1.01415e+08	1	0
# Backtracking failed.
# 0.3479792861226868	6824507.846220622	6824507.846220622	11373.410690564011	6813134.432793538	0.002736521927925181
# target angle:  0.32038288481911675
# 0	8.47298e+06	1.00899e+08	1.00899e+08	1	0
# Backtracking failed.
# 0.3908446009086704	6853433.357027334	6853433.357027334	5177.440820939799	6848255.914139718	0.0020666781863329198
# target angle:  0.35627109237176274
# 0	8.49868e+06	1.00178e+08	1.00178e+08	1	0
# Backtracking failed.
# 0.4338509746818128	6893906.457597847	6893906.457597847	13961.95400941018	6879944.498599101	0.004989335952059674
# target angle:  0.39215929992440873
# 0	8.53182e+06	9.92587e+07	9.92587e+07	1	0
# Backtracking failed.
# ...
